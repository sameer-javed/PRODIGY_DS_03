# %% [markdown]
# # Task requirments
#
# Build a Decision tree classifier to predict wheather a customer will buy a product or service based on their demographic and behaviorial data.
#
# data set used = ( https://archive.ics.uci.edu/dataset/222/bank+marketing )
#
# About data = The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution.
#
# Meta data = ( 45211 rows )  and ( 17 Columns )

# %% [markdown]
# # Loading data set and performing Some EDA

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\reals\Desktop\prodigy_task_1\task 03\bank-full.csv")
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Creating X and Y variables 
x = df.drop(columns={'y'})
y = df['y']

# %%
x.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %% [markdown]
# # Label Encoding the Categorical data

# %%
le = LabelEncoder()
x['age'] = le.fit_transform(x['age'])
x['job'] = le.fit_transform(x['job'])
x['marital'] = le.fit_transform(x['marital'])
x['education'] = le.fit_transform(x['education'])
x['default'] = le.fit_transform(x['balance'])
x['housing'] = le.fit_transform(x['housing'])
x['loan'] = le.fit_transform(x['loan'])
x['contact'] = le.fit_transform(x['contact'])
x['day'] = le.fit_transform(x['day'])
x['month'] = le.fit_transform(x['month'])
x['duration'] = le.fit_transform(x['duration'])
x['campaign'] = le.fit_transform(x['campaign'])
x['pdays'] = le.fit_transform(x['pdays'])
x['previous'] = le.fit_transform(x['previous'])
x['poutcome'] = le.fit_transform(x['poutcome'])

# %%
x
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       40    4        1          2     3036     2143        1     0        2
# 1       26    9        2          1      945       29        1     0        2
# 2       15    2        1          1      918        2        1     1        2
# 3       29    1        1          3     2420     1506        1     0        2
# 4       15   11        2          3      917        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   33    9        1          2     1741      825        0     0        0
# 45207   53    5        0          0     2639     1729        0     0        0
# 45208   54    5        1          1     5455     5715        0     0        0
# 45209   39    1        1          1     1584      668        0     0        1
# 45210   19    2        1          1     3779     2971        0     0        0
#
# ...

# %%
y = le.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %% [markdown]
# # Splitting the data to train test split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
X_train
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 31214   19    9        1          2     1465      549        0     0        0
# 12151   15    0        1          1      805     -111        1     1        2
# 19014   41    5        1          1     6728    12438        0     0        0
# 6377    27    2        1          0      816     -100        1     0        2
# 33726   12    8        2          0     2441     1527        0     0        1
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 31962   13    1        1          1     2322     1406        1     1        0
# 23452   41    4        1          2     2498     1585        0     0        1
# 23775   21    4        1          2      899      -17        1     1        0
# 37135   14    9        1          1      279     -684        1     0        0
# 27098   35    1        1          1     2685     1777        1     0        0
#
# ...

# %%
X_test
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 14458   14    9        2          2     1334      418        0     1        0
# 42532   14    0        2          1     1047      131        1     0        0
# 15048   12    7        1          1     2202     1286        1     1        0
# 40121    2    0        2          1     1252      336        0     1        0
# 27812   10   10        2          1      939       23        0     0        0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 12327   10    1        1          0     1618      702        1     0        2
# 18978   29    2        1          1     1234      318        0     0        0
# 4078    30    9        1          1     1438      522        1     0        2
# 26474   12    7        0          1      994       78        1     0        0
# 4330    27    4        1          3     6369     9051        1     0        2
#
# ...

# %%
Y_train
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
Y_test
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %% [markdown]
# # Creating a model Using Decision Tree Classifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, Y_test)
# Out:
# 0.8771425411920822

# %%
model.predict(X_test.iloc[0].values.reshape(1, -1))
# Out:
# c:\Users\reals\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict([[14,0,2,1,1047,131,1,0,0,20,2,322,0,186,1,2]])
# Out:
# c:\Users\reals\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
